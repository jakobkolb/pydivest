# %% [markdown]
# # Comparison of micro model and mean approximation for different imitation prob. terms

# %% [markdown]
# I run both models for various values of the rewiring probability $\phi$ and the total factor productivity in the dirty sector $b_d$ and evaluate the results in the following, to see, which effect different interaction terms would have.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from plot_routines import plot_routines

# %%
# Loading the data into a plotting tool class.
micro_path = macro_path = '/home/jakob/Project_Divestment/PyDivestment/output_data/test_output/P1/'
micro_selector = 'model = 1'
macro_selector = 'model = 2'
ptr = plot_routines(micro_path=micro_path, macro_path=macro_path, micro_selector=micro_selector, macro_selector=macro_selector)

# %% [markdown]
# Imitation probability of the form
#
# $\frac{1}{2} ( \tanh(wi - wj) + 1)$
#
# which in the macro model is approximated as
#
# $\frac{1}{2} (wi-wj+1)$
#
# leads to astonishingly good agreement of micro model and approximation. See below

# %%
figure = ptr.mk_4plots({'b_d': 1.25, 'phi': .5, 'interaction': 0}, 
                       upper_limits=[1, 85, 20, 15, 10], 
                       legend_locations=[4, 7, 7, 7], 
                       tmax=900)

# %% [markdown]
# Yet for an imitation probability of the form
#
# $\frac{1}{1 + \exp(-8 (wi-wj)/(wi + wj))}$
#
# as proposed by traulsen et al. 2008, the agreement betwen micro model and approximation becomes significantly worse - even though, the functional form is NOT approximated.

# %%
figure = ptr.mk_4plots({'b_d': 1.25, 'phi': .5, 'interaction': 1}, 
                       upper_limits=[1, 85, 18.5, 15, 10], 
                       legend_locations=[4, 7, 7, 7],
                       tmax=900)
figure.savefig('micro_macro_comparison.pdf')

# %% [markdown]
# And for an equally scale invariant but simpler interaction probabiltity such as
#
# $\frac{1}{2} \frac{wi-wj}{wi+wj}$
#
# the discrepancies are even bigger. See below:

# %%
figure = ptr.mk_4plots({'b_d': 1.25, 'phi': .5, 'interaction': 2}, 
                       lower_limits=[-.5, 0, 0, 0, 0],
                       upper_limits=[.75, 85, 18, 12, 10], 
                       legend_locations=[4, 7, 7, 7],
                       tmax=900)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-2c861f631cfe> in <module>()
#       3                        upper_limits=[.75, 85, 18, 12, 10],
#       4                        legend_locations=[4, 7, 7, 7],
# ----> 5                        tmax=900)
#
# ~/Project_Divestment/PyDivestment/evaluation_notebooks/plot_routines.py in mk_4plots(self, selector, upper_limits, lower_limits, legend_locations, tmax, tmin)
#     156         local_datasets = []
#     157         for d in self.data_sets:
# --> 158             local_datasets.append(d.xs(list(selector.values()), level=list(selector.keys())))
#     159
#     160         l_vars = len(self.variable_combos)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    2321         if level is not None:
#    2322             loc, new_ax = labels.get_loc_level(key, level=level,
# -> 2323                                                drop_level=drop_level)
#    2324
#    2325             # create the tuple of the indexer
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2184             result = None
#    2185             for lev, k in zip(level, key):
# -> 2186                 loc, new_index = self.get_loc_level(k, level=lev)
#    2187                 if isinstance(loc, slice):
#    2188                     mask = np.zeros(len(self), dtype=bool)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2280                 return indexer, maybe_droplevels(indexer, ilevels, drop_level)
#    2281         else:
# -> 2282             indexer = self._get_level_indexer(key, level=level)
#    2283             return indexer, maybe_droplevels(indexer, [level], drop_level)
#    2284
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2360         else:
#    2361
# -> 2362             loc = level_index.get_loc(key)
#    2363             if isinstance(loc, slice):
#    2364                 return loc
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2

# %% [markdown]
# It even seems like the imitation probability is too small to allow for propper discrimination of the two investment options. (But in case, this could be fixed by introducing a parameter..)

# %% [markdown]
# We can systematically check the differences for other values of phi and by calculating the L2 norm between e.g. the x trajectories of micro and macro model results:

# %%
micro_data = ptr.micro_mean
macro_data = ptr.macro_mean

fig = plt.figure()
ax = fig.add_subplot(111)

colors = 'bck'
interaction_labels = 'ABC'

for i, interaction in enumerate([0, 1, 2]):
    mid = micro_data.xs(level=['b_d', 'interaction'], key=[1.25, interaction])
    mad = macro_data.xs(level=['b_d', 'interaction'], key=[1.25, interaction])
    dif = (mid - mad)**2
    x = dif[['x']].groupby(level=[0]).sum()
    ax.plot(x.index.values, x.values, label=f'interaction: {interaction_labels[i]}', color = colors[i])
ax.legend()
ax.set_xlabel('$\phi$')
ax.set_ylabel('$L_2$')
# Out:
# Text(0,0.5,'$L_2$')

# %% [markdown]
# So, this confirms, that over almost the entire range of $\phi$, the first interaction term leads to be best approximation.

# %%
fig = plt.figure(figsize=(13, 3.5))
ax1 = fig.add_subplot(141)
ptr.mk_opinon_plots({'b_d': 1.25, 'phi': .43, 'interaction': 0}, 
                   y_limits=[-1, 1],
                   legend_location=0,
                   ax=ax1,
                   legend=False)
ax1.annotate('A)', xy=(40, .85))
ax2 = fig.add_subplot(142)
ptr.mk_opinon_plots({'b_d': 1.25, 'phi': .43, 'interaction': 1}, 
                   y_limits=[-1, 1],
                   legend_location=0,
                   ax=ax2,
                   legend=False,
                   y_ticks=False)
ax2.annotate('B)', xy=(40, .85))
ax3 = fig.add_subplot(143)
ptr.mk_opinon_plots({'b_d': 1.25, 'phi': .43, 'interaction': 2}, 
                   y_limits=[-1, 1],
                   legend_location=0,
                   ax=ax3,
                   y_ticks=False)
ax3.annotate('C)', xy=(40, .85))

ax4 = fig.add_subplot(144)

colors = 'bck'
interaction_labels = 'ABC'

for i, interaction in enumerate([0, 1, 2]):
    mid = micro_data.xs(level=['b_d', 'interaction'], key=[1.25, interaction])
    mad = macro_data.xs(level=['b_d', 'interaction'], key=[1.25, interaction])
    dif = (mid - mad)**2
    x = dif[['x']].groupby(level=[0]).sum()
    ax4.plot(x.index.values, x.values, label=f'interaction: {interaction_labels[i]}', color = colors[i])
ax4.legend()
ax4.set_xlabel('$\phi$')
ax4.set_ylabel('$L_2$')

fig.tight_layout()
fig.savefig('interactions123.pdf')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: 0.43
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-71381a83ff15> in <module>()
#       5                    legend_location=0,
#       6                    ax=ax1,
# ----> 7                    legend=False)
#       8 ax1.annotate('A)', xy=(40, .85))
#       9 ax2 = fig.add_subplot(142)
#
# ~/Project_Divestment/PyDivestment/evaluation_notebooks/plot_routines.py in mk_opinon_plots(self, selector, y_limits, legend_location, ax, legend, x_limits, x_label, y_ticks)
#      98         local_datasets = []
#      99         for d in self.data_sets:
# --> 100             local_datasets.append(d.xs(list(selector.values()), level=list(selector.keys())))
#     101
#     102         variables = self.variable_combos[0]
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    2321         if level is not None:
#    2322             loc, new_ax = labels.get_loc_level(key, level=level,
# -> 2323                                                drop_level=drop_level)
#    2324
#    2325             # create the tuple of the indexer
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2184             result = None
#    2185             for lev, k in zip(level, key):
# -> 2186                 loc, new_index = self.get_loc_level(k, level=lev)
#    2187                 if isinstance(loc, slice):
#    2188                     mask = np.zeros(len(self), dtype=bool)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_loc_level(self, key, level, drop_level)
#    2280                 return indexer, maybe_droplevels(indexer, ilevels, drop_level)
#    2281         else:
# -> 2282             indexer = self._get_level_indexer(key, level=level)
#    2283             return indexer, maybe_droplevels(indexer, [level], drop_level)
#    2284
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    2360         else:
#    2361
# -> 2362             loc = level_index.get_loc(key)
#    2363             if isinstance(loc, slice):
#    2364                 return loc
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/numeric.py in get_loc(self, key, method, tolerance)
#     402             pass
#     403         return super(Float64Index, self).get_loc(key, method=method,
# --> 404                                                  tolerance=tolerance)
#     405
#     406     @cache_readonly
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: 0.43

# %%
fig = plt.figure(figsize=(9, 3))
ax1 = fig.add_subplot(131)
ptr.mk_opinon_plots({'b_d': 1.25, 'phi': .43, 'interaction': 0}, 
                   y_limits=[-1, 1],
                   legend_location=0,
                   ax=ax1,
                   legend=False)
ax1.annotate('A)', xy=(40, .85))
ax2 = fig.add_subplot(132)
ptr.mk_opinon_plots({'b_d': 1.25, 'phi': .43, 'interaction': 1}, 
                   y_limits=[-1, 1],
                   legend_location=0,
                   ax=ax2,
                   legend=False,
                   y_ticks=False)
ax2.annotate('B)', xy=(40, .85))

ax4 = fig.add_subplot(133)

colors = 'bck'
interaction_labels = 'ABC'

for i, interaction in enumerate([0, 1]):
    mid = micro_data.xs(level=['b_d', 'interaction'], key=[1.25, interaction])
    mad = macro_data.xs(level=['b_d', 'interaction'], key=[1.25, interaction])
    dif = (mid - mad)**2
    x = dif[['x']].groupby(level=[0]).sum()
    ax4.plot(x.index.values, x.values, label=f'interaction: {interaction_labels[i]}', color = colors[i])
ax4.legend()
ax4.set_xlabel('$\phi$')
ax4.set_ylabel('$L_2$')

fig.tight_layout()
fig.savefig('interactions12.pdf')
